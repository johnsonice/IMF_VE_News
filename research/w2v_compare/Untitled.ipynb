# %%
import pandas as pd

# %%
argentina_df = pd.read_csv('Min1_AllCountry/argentina_month_time_series.csv')

# %%
argentina_df.head()
# Out:
#   Unnamed: 0   adverse  inability  possibly  severely   predict      warn  \
# 0    1980-01  0.010590   0.084717  0.201203  0.031769  1.016605  0.593019
# 1    1980-02  0.016953   0.067810  0.220384  0.000000  0.779820  0.491625
# 2    1980-03  0.039234   0.137320  0.196171  0.000000  0.980854  0.470810
# 3    1980-04  0.168416   0.140347  0.070173  0.042104  1.164880  0.477180
# 4    1980-05  0.000000   0.048921  0.244606  0.000000  1.663324  1.125190
#
#    mitigate   suggest   deficit  ...  successfully  question    expose  \
# 0  0.052948  1.016605  0.180024  ...      0.063538  0.180024  0.158844
# 1  0.101716  0.796772  0.135621  ...      0.084763  0.101716  0.033905
# 2  0.078468  1.000471  0.274639  ...      0.137320  0.078468  0.058851
# 3  0.112278  1.052602  0.308763  ...      0.042104  0.056139  0.070173
# 4  0.195685  1.467639  0.048921  ...      0.000000  0.000000  0.048921
#
#        hurt       can  positive  resilience    unease  exacerbate       say
# 0  0.180024  6.565571  0.042359    0.021179  0.063538    0.137665  0.698916
# 1  0.033905  4.848444  0.033905    0.000000  0.101716    0.016953  0.559436
# 2  0.078468  5.610483  0.235405    0.156937  0.058851    0.039234  0.588512
# 3  0.014035  4.210408  0.126312    0.014035  0.042104    0.056139  0.617527
# 4  0.048921  7.289272  0.048921    0.000000  0.000000    0.048921  1.271953
#
# [5 rows x 125 columns]

# %%
grouped_words = pd.read_csv('grouped_search_words_final.csv')

# %%
grouped_words
# Out:
#    fear_language         risk_language hedging_language opinion_language  \
# 0           fear                  warn              may              say
# 1        concern                  risk         possibly             feel
# 2         afraid                threat        uncertain          predict
# 3        anxious      financial&hazard            maybe             tell
# 4            NaN  financial&contagious              can          believe
# ..           ...                   ...              ...              ...
# 92           NaN                   NaN              NaN              NaN
# 93           NaN                   NaN              NaN              NaN
# 94           NaN                   NaN              NaN              NaN
# 95           NaN                   NaN              NaN              NaN
# 96           NaN                   NaN              NaN              NaN
#
#      crisis_language positive_sentiment_language negative_sentiment_language  \
# 0   financial_crisis                        able                      abrupt
# 1         depression                      enable                     adverse
# 2                NaN                  adequately                   adversely
# 3                NaN                      benign                   aggravate
# 4                NaN                     buoyant                         bad
# ..               ...                         ...                         ...
# 92               NaN                         NaN                         NaN
# 93               NaN                         NaN                         NaN
# 94               NaN                         NaN                         NaN
# 95               NaN                         NaN                         NaN
# 96               NaN                         NaN                         NaN
#
#    agg_all_other_sentiments agg_other_and_negative all_language
# 0                      fear                   fear         fear
# 1                   concern                concern         warn
# 2                    afraid                 afraid         risk
# 3                   anxious                anxious       danger
# 4                      warn                   warn          may
# ..                      ...                    ...          ...
# 92                      NaN           unexpectedly          NaN
# 93                      NaN             vulnerable          NaN
# 94                      NaN               weakness          NaN
# 95                      NaN                 worsen          NaN
# 96                      NaN             writedowns          NaN
#
# [97 rows x 10 columns]

# %%
print(list(grouped_words['negative_sentiment_language'].values))
# Out:
# ['abrupt', 'adverse', 'adversely', 'aggravate', 'bad', 'burden', 'challenge', 'closure', 'contraction', 'costly', 'damage', 'danger', 'deficit', 'dent', 'destabilise', 'deteriorate', 'deterioration', 'deterioration', 'difficult', 'discourage', 'downgrade', 'drag', 'erode', 'erosion', 'exacerbate', 'expose', 'fear', 'force', 'fragility', 'gloomy', 'hurt', 'illiquid', 'impairment', 'inability', 'jeopardise', 'lose', 'negative', 'pose', 'question', 'repercussion', 'risky', 'severely', 'shortfall', 'spiral', 'squeeze', 'stagnate', 'strain', 'stress', 'struggle', 'suffer', 'threaten', 'turbulent', 'unable', 'undermine', 'unease', 'unexpectedly', 'vulnerable', 'weakness', 'worsen', 'writedowns', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]

# %%
pos = ['able' 'enable' 'adequately' 'benign' 'buoyant' 'buoyancy' 'comfortable'
 'confident' 'enhance' 'favorable' 'favourably' 'healthy' 'improve'
 'improvement' 'mitigate' 'positive' 'positively' 'profits' 'rebound'
 'recover' 'recovery' 'resilience' 'resilient' 'solid' 'sound' 'stabilise'
 'stabilize' 'success' 'successful' 'successfully']

# %%
pos
# Out:
# ['ableenableadequatelybenignbuoyantbuoyancycomfortableconfidentenhancefavorablefavourablyhealthyimproveimprovementmitigatepositivepositivelyprofitsreboundrecoverrecoveryresilienceresilientsolidsoundstabilisestabilizesuccesssuccessfulsuccessfully']
