# %%
import pandas as pd
import numpy as np

# %%
def create_agg_index(index_words, all_word_freq):
    agg_index = pd.Series(name=index_words.name, index=all_word_freq.index)
    
    for ind in all_word_freq.index:
        agg_index[ind] = all_word_freq[index_words.dropna().values].loc[ind].sum()
    
    return agg_index

# %%
reference_arg = pd.read_csv('argentina_month_time_series.csv')

# %%
reference_arg
# Out:
#     Unnamed: 0  severely   concern  improvement      able   anxious  \
# 0      1980-01  0.031769  0.137665     0.243562  0.412996  0.190613
# 1      1980-02  0.000000  0.135621     0.254289  0.423815  0.152573
# 2      1980-03  0.000000  0.078468     0.490427  0.255022  0.117702
# 3      1980-04  0.042104  0.056139     0.505249  0.238590  0.070173
# 4      1980-05  0.000000  0.000000     0.146764  0.146764  0.048921
# ..         ...       ...       ...          ...       ...       ...
# 465    2018-12  0.575904  1.612532     2.188436  2.994702  1.612532
# 466    2019-01  0.530363  3.447361     2.916998  1.856272  0.265182
# 467    2019-02  0.458505  0.458505     2.751032  1.834021  1.375516
# 468    2019-03  0.311090  1.555452     2.799813  2.488723  1.866542
# 469    2019-04  0.613874  4.910988     0.613874  3.069368  0.000000
#
#      writedowns        may  deterioration     erode  ...  challenge  \
# 0      0.042359   3.092172       0.031769  0.074127  ...   0.042359
# 1      0.000000   2.525937       0.067810  0.084763  ...   0.186479
# 2      0.078468   2.275581       0.137320  0.000000  ...   0.156937
# 3      0.084208   1.613990       0.112278  0.070173  ...   0.112278
# 4      0.000000   5.136735       0.048921  0.048921  ...   0.000000
# ..          ...        ...            ...       ...  ...        ...
# 465    0.115181  15.203870       0.575904  0.691085  ...   1.727713
# 466    0.000000  15.910899       1.060727  0.795545  ...   2.386635
# 467    0.458505   4.585053       4.126547  1.834021  ...   1.834021
# 468    0.155545  12.754705       1.555452  0.622181  ...   0.466636
# 469    0.000000  15.346839       1.841621  0.613874  ...   0.613874
#
#      unexpectedly  struggle    worsen  favorable  downgrade  adequately  \
# 0        0.211793  0.116486  0.074127   0.010590   0.105896    0.042359
# 1        0.135621  0.050858  0.050858   0.033905   0.067810    0.016953
# 2        0.255022  0.235405  0.117702   0.039234   0.196171    0.098085
# 3        0.196486  0.084208  0.098243   0.140347   0.042104    0.056139
# 4        0.097843  0.097843  0.000000   0.000000   0.097843    0.000000
# ..            ...       ...       ...        ...        ...         ...
# 465      1.612532  1.727713  1.266989   0.230362   0.921447    0.230362
# 466      4.242906  1.325908  1.325908   0.530363   2.651816    0.000000
# 467      0.917011  1.834021  2.292526   0.917011   0.917011    0.000000
# 468      2.644268  2.333178  1.555452   0.622181   6.688443    0.155545
# 469      3.683241  0.613874  1.227747   1.227747   3.683241    0.000000
#
#      discourage  impairment    strain
# 0      0.063538    0.042359  0.074127
# 1      0.016953    0.000000  0.067810
# 2      0.039234    0.078468  0.137320
# 3      0.042104    0.084208  0.098243
# 4      0.097843    0.000000  0.000000
# ..          ...         ...       ...
# 465    0.460723    0.115181  0.921447
# 466    0.265182    0.000000  1.060727
# 467    0.000000    0.458505  0.458505
# 468    0.155545    0.155545  0.622181
# 469    0.613874    0.000000  1.227747
#
#
# [470 rows x 124 columns]

# %%
reference_arg.iloc[0].sum()
# Out:
# 28.306082683835985

# %%
reference_arg.iloc[1].sum()
# Out:
# 22.83515291245677

# %%
sims_map = pd.read_csv('all_sims_maps.csv')

# %%
sims_map = sims_map.set_index('Unnamed: 0')
sims_map
# Out:
#                fed_pos    fed_neg w2v_pos       w2v_neg w2v_refined_0_pos  \
# Unnamed: 0
# 0                 able     abrupt  unable        sudden            oblige
# 1               enable    adverse  oblige      dramatic               try
# 2           adequately  adversely     try   ignominious              need
# 3               benign  aggravate    need      untimely             eager
# 4              buoyant        bad   eager    unexpected             allow
# ...                ...        ...     ...           ...               ...
# 1015               NaN        NaN     NaN  unexpectedly               NaN
# 1016               NaN        NaN     NaN    vulnerable               NaN
# 1017               NaN        NaN     NaN      weakness               NaN
# 1018               NaN        NaN     NaN        worsen               NaN
# 1019               NaN        NaN     NaN    writedowns               NaN
#
#            w2v_refined_0_neg w2v_refined_1_pos w2v_refined_1_neg  \
# Unnamed: 0
# 0                     sudden              need            sudden
# 1                   dramatic             allow          dramatic
# 2                ignominious              keen       ignominious
# 3                   untimely            enable          untimely
# 4                 unexpected           ability        unexpected
# ...                      ...               ...               ...
# 1015                     NaN               NaN               NaN
# 1016                     NaN               NaN               NaN
# 1017                     NaN               NaN               NaN
# 1018                     NaN               NaN               NaN
# 1019                     NaN               NaN               NaN
#
#            w2v_refined_2_pos w2v_refined_2_neg
# Unnamed: 0
# 0                      allow            sudden
# 1                       keen          dramatic
# 2                     enable       ignominious
# 3                    ability          untimely
# 4                      ready        unexpected
# ...                      ...               ...
# 1015                     NaN               NaN
# 1016                     NaN               NaN
# 1017                     NaN               NaN
# 1018                     NaN               NaN
# 1019                     NaN               NaN
#
# [1020 rows x 10 columns]

# %%
arg_index_df = pd.DataFrame(index=reference_arg.index)
for col in sims_map.columns:
    agg_index = create_agg_index(sims_map[col].dropna(), reference_arg)
    print(agg_index)
    arg_index_df = arg_index_df.join(agg_index)
arg_index_df
# Out:
# C:\Users\Alex P\Dev\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# Date
# 1980-01     3.568706
# 1980-02     3.288805
# 1980-03     5.414313
# 1980-04     3.873575
# 1980-05     2.543907
#              ...
# 2018-12    35.475697
# 2019-01    35.003978
# 2019-02    37.597432
# 2019-03    39.041842
# 2019-04    40.515654
# Name: fed_pos, Length: 470, dtype: float64
# Date
# 1980-01     6.682057
# 1980-02     5.475690
# 1980-03     7.101381
# 1980-04     5.824398
# 1980-05     4.305073
#              ...
# 2018-12    60.239576
# 2019-01    76.902678
# 2019-02    93.993581
# 2019-03    85.394307
# 2019-04    97.605893
# Name: fed_neg, Length: 470, dtype: float64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-dc19f7da5de3> in <module>
#       1 arg_index_df = pd.DataFrame(index=reference_arg.index)
#       2 for col in sims_map.columns:
# ----> 3     agg_index = create_agg_index(sims_map[col].dropna(), reference_arg)
#       4     print(agg_index)
#       5     arg_index_df = arg_index_df.join(agg_index)
#
# <ipython-input-14-9500f5158b8f> in create_agg_index(index_words, all_word_freq)
#       3
#       4     for ind in all_word_freq.index:
# ----> 5         agg_index[ind] = all_word_freq[index_words.dropna().values].loc[ind].sum()
#       6
#       7     return agg_index
#
# ~\Dev\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2910             if is_iterator(key):
#    2911                 key = list(key)
# -> 2912             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2913
#    2914         # take() does not accept boolean indexers
#
# ~\Dev\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\Dev\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['uccess', 'somewhat', 'slump', 'mproved', 'appealingly', 'relatively_benign', 'acceleration', 'comfy', 'hope', 'stagnant', 'mprovement', 'efficiently', 'consistently', 'allow', 'satisfactorily', 'clearly', 'steady', 'closely_align', 'depress', 'eliminate', 'convince', 'breakthrough', 'fall', 'bouncy', 'mawkish', 'keen', 'ecovery', 'reflate', 'minimise', 'toughness', 'wish', 'vigorously', 'effectively', 'deleverage', 'negate', 'decline', 'impressive', 'prolt', 'assist', 'differently', 'need', 'ability', 'eager', 'supportive', 'profoundly', 'rebalance', 'prowess', 'suc_cessful', 'ameliorate', 'oblige', 'strong', 'unfavorable', 'cautiously', 'readjust', 'excite', 'nascent_recovery', 'prols', 'accommodative', 'restore_confidence', 'downturn', 'fully', 'slowdown', 'choke_off', 'quantify', 'firmness', 'evaporate', 'sustainable', 'maximize', 'ensure', 'want', 'robust', 'bolster', 'subdue', 'durability', 'uplift', 'sluggishness', 'prfits', 'recoup', 'profts', 'prolts', 'solidly', 'enviable', 'agreeable', 'bearish', 'sucessful', 'thoroughly', 'rebound_strongly', 'kickstart', 'offset', 'dip', 'prudently', 'toppy', 'outperformance', 'rapidly', 'erase', 'strengthen', 'survival', 'dynamically', 'accelerate', 'keenly', 'decent', 'bounce', 'complement', 'unexciting', 'whimsy', 'good', 'sturdy', 'normalise', 'softness', 'reduce', 'deflate', 'help', 'bleak', 'slight_improvement', 'encourage', 'require', 'proflts', 'stabilisation', 'swiftly', 'deflationary', 'sympathetically', 'adamant', 'impair', 'prestigious', 'bounce_back', 'perverse', 'ambition', 'claw_back', 'vitality', 'subside', 'sucess', 'assure', 'optimise', 'upswing', 'retreat', 'warily', 'reasonably_confident', 'unsatisfied', 'unfavourably', 'favourable', 'sufficiently_robust', 'regain', 'unhealthy', 'revival', 'safe', 'facilitate', 'kindly', 'inadequately', 'hugely_successful', 'climb', 'disadvantageous', 'uninspiring', 'skilfully', 'downbeat', 'unearthly', 'try', 'avoid', 'recalibrate', 'cyclical_upswing', 'respectable', 'stable', 'correctly', 'weak', 'slippage', 'cautiously_optimistic', 'falter', 'cautious', 'recede', 'sufficient', 'sanguine', 'happy', 'tuneful', 'risk_averse', 'naturally', 'predictable', 'doldrums', 'tumble', 'innovative', 'robustly', 'intensively', 'reinforce', 'comsortable', 'slide', 'rebind', 'severely_depress', 'hospitable', 'accurately', 'susficient', 'sufficiently', 'plangent', 'con-_cerned', 'sluggish', 'mute', 'hopeful', 'disappoint', 'upturn', 'adequate', 'distinctly', 'robustness', 'revive', 'boost', 'prost', 'aggressively', 'incentivise', 'minimize', 'mprove', 'neutralise', 'properly', 'soften', 'bullish_mood', 'upward_trend', 'lessen', 'dissonant', 'empower', 'poorly', 'maintain', 'turnround', 'plunge', 'uptick', 'consident', 'uncomsortable', 'synthesiser', 'magnify', 'remarkably_resilient', 'warmly', 'relax', 'stabilization', 'propitious', 'reduction', 'energetically', 'growth', 'ready', 'prolits', 'slip', 'profl', 'uncomfortable', 'counteract', 'suc_cess', 'unconvinced', 'restore', 'sublimely', 'proit', 'plummet', 'profitable', 'portentous', 'unfavourable', 'sophisticate', 'seek', 'vulnerability', 'bullish', 'alleviate', 'soporific', 'astringent', 'prots', 'appropriately', 'ambitious', 'turnaround', 'profi', 'uccessful', 'increase', 'proflt', 'incline', 'weaken', 'optimistic', 'sensitivity', 'surprisingly_resilient', 'succes', 'strength', 'succesful', 'maximise', 'important_determinant', 'accomplishment', 'underpin', 'tightness', 'remunerative', 'progress', 'greatly_enhance', 'bullish_sentiment', 'attractive', 'proits', 'reliable_indicator', 'stellar', 'worrisome', 'successfu', 'harshly', 'satisfactory', 'tinny', 'dynamism', 'regain_momentum', 'lacklustre', 'profitably', 'solidity', 'sceptical', 'inwardly', 'steadiness', 'achievement', 'outweigh', 'enough', 'upbeat', 'pleasant', 'recession', 'cessful', 'adequacy', 'luxurious', 'use', 'volatile', 'rigorously', 'successul', 'quirky', 'bounceback', 'mildly', 'profis', 'sceptically', 'unstab ...

# %%
sims_map
# Out:
#                fed_pos    fed_neg w2v_pos       w2v_neg w2v_refined_0_pos  \
# Unnamed: 0
# 0                 able     abrupt  unable        sudden            oblige
# 1               enable    adverse  oblige      dramatic               try
# 2           adequately  adversely     try   ignominious              need
# 3               benign  aggravate    need      untimely             eager
# 4              buoyant        bad   eager    unexpected             allow
# ...                ...        ...     ...           ...               ...
# 1015               NaN        NaN     NaN  unexpectedly               NaN
# 1016               NaN        NaN     NaN    vulnerable               NaN
# 1017               NaN        NaN     NaN      weakness               NaN
# 1018               NaN        NaN     NaN        worsen               NaN
# 1019               NaN        NaN     NaN    writedowns               NaN
#
#            w2v_refined_0_neg w2v_refined_1_pos w2v_refined_1_neg  \
# Unnamed: 0
# 0                     sudden              need            sudden
# 1                   dramatic             allow          dramatic
# 2                ignominious              keen       ignominious
# 3                   untimely            enable          untimely
# 4                 unexpected           ability        unexpected
# ...                      ...               ...               ...
# 1015                     NaN               NaN               NaN
# 1016                     NaN               NaN               NaN
# 1017                     NaN               NaN               NaN
# 1018                     NaN               NaN               NaN
# 1019                     NaN               NaN               NaN
#
#            w2v_refined_2_pos w2v_refined_2_neg
# Unnamed: 0
# 0                      allow            sudden
# 1                       keen          dramatic
# 2                     enable       ignominious
# 3                    ability          untimely
# 4                      ready        unexpected
# ...                      ...               ...
# 1015                     NaN               NaN
# 1016                     NaN               NaN
# 1017                     NaN               NaN
# 1018                     NaN               NaN
# 1019                     NaN               NaN
#
# [1020 rows x 10 columns]

# %%
arg_index_df
# Out:
#            fed_pos    fed_neg
# Date
# 1980-01   3.568706   6.682057
# 1980-02   3.288805   5.475690
# 1980-03   5.414313   7.101381
# 1980-04   3.873575   5.824398
# 1980-05   2.543907   4.305073
# ...            ...        ...
# 2018-12  35.475697  60.239576
# 2019-01  35.003978  76.902678
# 2019-02  37.597432  93.993581
# 2019-03  39.041842  85.394307
# 2019-04  40.515654  97.605893
#
# [470 rows x 2 columns]
