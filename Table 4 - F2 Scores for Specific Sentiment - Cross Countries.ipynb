# %% [markdown]
# ## Compile functions, import packages

# %%
import glob
import pandas as pd

# %% [markdown]
# # Import Data

# %%
# Eval file folders
pos_neg_eval_ff = 'C:\Repos\IMF_VE_News\csv_out\*' # Scores for new positive-negative
cross_country_ff = 'C:\Repos\IMF_VE_News\cross_compare_new\*' # Folders for cross-crisis comparison

# Display cross-crisis comparison folders
pos_neg_eval_folds = glob.glob(pos_neg_eval_ff)
print("Pos-neg eval files\n", pos_neg_eval_folds)

# Display cross-crisis comparison folders
cross_country_folds = glob.glob(cross_country_ff)
print("Cross country crisis folders\n", cross_country_folds)
# Out:
# Cross country crisis folders
#  ['C:\\Repos\\IMF_VE_News\\cross_compare_new\\CrossSection', 'C:\\Repos\\IMF_VE_News\\cross_compare_new\\IMF_GAP_0', 'C:\\Repos\\IMF_VE_News\\cross_compare_new\\IMF_GAP_6', 'C:\\Repos\\IMF_VE_News\\cross_compare_new\\IMF_Monthly_Starts', 'C:\\Repos\\IMF_VE_News\\cross_compare_new\\IMF_Monthly_Starts_Gap_3', 'C:\\Repos\\IMF_VE_News\\cross_compare_new\\IMF_Monthly_Starts_Gap_6', 'C:\\Repos\\IMF_VE_News\\cross_compare_new\\LoDuca', 'C:\\Repos\\IMF_VE_News\\cross_compare_new\\Min1_AllCountry', 'C:\\Repos\\IMF_VE_News\\cross_compare_new\\Min1_ReinhartRogoffAll', 'C:\\Repos\\IMF_VE_News\\cross_compare_new\\Min1_RomerRomer', 'C:\\Repos\\IMF_VE_News\\cross_compare_new\\ReinhartRogoff', 'C:\\Repos\\IMF_VE_News\\cross_compare_new\\RomerRomer']

# %%
# Cross-crisis comparisons
cross_comp_files = glob.glob(cross_country_folds[0]+'\*')
print(cross_comp_files)
# Display one ex
pd.read_csv(cross_comp_files[0]).head()
# Out:
# ['C:\\Repos\\IMF_VE_News\\cross_compare_new\\CrossSection\\cross_comparison.csv', 'C:\\Repos\\IMF_VE_News\\cross_compare_new\\CrossSection\\cross_comparison_monthly_IMF.csv']
#   classification_type  fear_language_recall  fear_language_prec  \
# 0     Min1_AllCountry              0.823529            0.153846
# 1           IMF_GAP_6              0.761290            0.103873
# 2           IMF_GAP_0              0.815175            0.579129
# 3              LoDuca              0.827957            0.124394
# 4      ReinhartRogoff              0.882353            0.138376
#
#    fear_language_f2  risk_language_recall  risk_language_prec  \
# 0          0.440252              0.836066            0.173469
# 1          0.335991              0.748428            0.100000
# 2          0.753733              0.804348            0.566955
# 3          0.388496              0.870000            0.146712
# 4          0.425170              0.913978            0.155963
#
# ...

# %%
# KR Crisis
cross_comp_files = glob.glob(cross_country_folds[0]+'\*')
print(cross_comp_files)
# Display one ex
print(pd.read_csv(eval_files[0]).head())
# Out:
#            sentiment  tp   fp  fn    recall  precision    fscore  Unnamed: 7  \
# 0            fed_pos  29  456  10  0.743590   0.059794  0.226209         NaN
# 1            fed_neg  38  465  10  0.791667   0.075547  0.273381         NaN
# 2            w2v_pos  26  427  12  0.684211   0.057395  0.214876         NaN
# 3            w2v_neg  40  442  12  0.769231   0.082988  0.289855         NaN
# 4  w2v_refined_2_pos  30  455  11  0.731707   0.061856  0.231125         NaN
#
#                  paired_scores  recall.1  precision.1  fscore.1
# 0                 tb_direction  0.615385     0.092664  0.289157
# 1                    vader*w2v  0.813910     0.076633  0.277526
# 2          vader_direction*w2v  0.737500     0.076276  0.269126
# 3                  w2v_refined  0.779315     0.074014  0.267613
# 4  vader_direction*w2v_refined  0.794715     0.072620  0.265373

# %% [markdown]
# # Separate Data by Crisis Def

# %% [markdown]
# # Test Resistance of KR crisis def against identification criteria

# %% [markdown]
# #
